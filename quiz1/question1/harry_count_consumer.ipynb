# %%
# !pip install kafka-python

# %%
from kafka import KafkaConsumer

# %%
consumer = KafkaConsumer('espresso-count-stream', group_id='harry-count-py', bootstrap_servers=['ec2-13-229-46-113.ap-southeast-1.compute.amazonaws.com:9092'])

# %%
for msg in consumer:
  print(msg.value.decode('utf-8'))
