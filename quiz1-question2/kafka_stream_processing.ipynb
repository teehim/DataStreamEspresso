# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaratnida/Data_Streaming_and_Realtime_Analytics/blob/main/Week6_spark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
# !pip install confluent-kafka

# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget https://downloads.apache.org/spark/spark-2.4.8/spark-2.4.8-bin-hadoop2.7.tgz
# !tar -xvf spark-2.4.8-bin-hadoop2.7.tgz
# !pip install findspark

# %%
# !wget "https://repo1.maven.org/maven2/org/apache/spark/spark-streaming-kafka-0-8-assembly_2.11/2.4.8/spark-streaming-kafka-0-8-assembly_2.11-2.4.8.jar"
# Out:
# --2021-09-25 01:54:06--  https://repo1.maven.org/maven2/org/apache/spark/spark-streaming-kafka-0-8-assembly_2.11/2.4.8/spark-streaming-kafka-0-8-assembly_2.11-2.4.8.jar
# Resolving repo1.maven.org (repo1.maven.org)... 199.232.192.209, 199.232.196.209
# Connecting to repo1.maven.org (repo1.maven.org)|199.232.192.209|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12002039 (11M) [application/java-archive]
# Saving to: ‘spark-streaming-kafka-0-8-assembly_2.11-2.4.8.jar’
#
# spark-streaming-kaf 100%[===================>]  11.45M  --.-KB/s    in 0.1s
#
# 2021-09-25 01:54:06 (92.0 MB/s) - ‘spark-streaming-kafka-0-8-assembly_2.11-2.4.8.jar’ saved [12002039/12002039]

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.8-bin-hadoop2.7"
os.environ['PYSPARK_SUBMIT_ARGS'] = '--jars /content/spark-streaming-kafka-0-8-assembly_2.11-2.4.8.jar pyspark-shell'

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.ml.feature import Normalizer, StandardScaler
import random
import pyspark
import sys
from pyspark import SparkContext, SparkConf
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils
from uuid import uuid1
import time

kafka_topic_name = "stream-expresso-input"
kafka_bootstrap_servers = 'ec2-13-229-46-113.ap-southeast-1.compute.amazonaws.com:9092'

# %%
sc = pyspark.SparkContext()
ssc = StreamingContext(sc,1)

# %%
tf_idf_table = list()
df_table = dict()

tf_idf_broadcast = sc.broadcast(tf_idf_table)
tf_idf_broadcast.value.append(dict())
df_broadcast = sc.broadcast(df_table)

doc_count = sc.accumulator(0)

print(tf_idf_broadcast.value)
print(df_broadcast.value)
# Out:
# [{}]
# {}

# %% [markdown]
# # Calculate TF

# %%
import math
def calculate_tf(data_dict):
    total = 0
    result = dict()
    for i in data_dict.values():
        total += i
        
    for k, v in data_dict.items():
        result[k] = v / total
    return result

# %% [markdown]
# # Calculate IDF

# %%
def calculate_idf():

  word_appear_count = {} 
  N = len(tf_idf_broadcast.value)
  #Count N of word to find that word appear each time from every page
  for word in df_broadcast.value: 
    for doc in tf_idf_broadcast.value:
      for key, value in doc["tf"].items():  
        if word == key and word not in word_appear_count:
          word_appear_count[word] = 1
        elif word == key and word in word_appear_count:
          word_appear_count[word] += 1
  
  #Calculate IDF
  for doc in tf_idf_broadcast.value:
    result_idf = {}
    for key, value in doc["tf"].items():
      idf = math.log10((1+N)/(1+word_appear_count[key])) + 1
      result_idf[key] = idf
    doc["idf"] = result_idf

# %% [markdown]
# # Public Most important words to Consumer

# %%
from confluent_kafka import Producer

def delivery_report(err, msg):
    if err is not None:
        print('Message delivery failed: {}'.format(err))
    else:
        print('Message delivered to {} [{}]'.format(msg.topic(), msg.partition()))


def publishToKafkaOutput(json):

  kafka_output_topic_name = "stream-expresso-output"

  p = Producer({'bootstrap.servers': kafka_bootstrap_servers, 'message.max.bytes': '2048576'})
  p.poll(0)
  p.produce(kafka_output_topic_name, value=json, callback=delivery_report)
  p.flush()

# %% [markdown]
# # Processing TF IDF

# %%
import json
def convertToJson(list):

  results = {}
  for index, page in enumerate(list):
    pageKey = f"page{index+1}"
    results[pageKey] = page

  return json.dumps(results, indent = 4)

def calculateTFIDFAndGetTop(dict, top):
  results = {} 
  top_dict = {}
  for key_tf, value_tf in dict['tf'].items():
    for key_idf, value_idf in dict['idf'].items():
      if key_tf == key_idf:
        results[key_tf] = value_tf * value_idf

  sort_orders = sorted(results.items(), key=lambda x: x[1], reverse=True)[:top]
  
  for item in sort_orders:
    top_dict[item[0]] = item[1]
  
  return top_dict

def is_new_page(data):
  return data == '#####'

def is_end_of_the_book(data):
  return data == '@@@@@@@'

def echo(time, rdd):
  datas = rdd.collect()
  df_page = {}
  if len(datas) > 0:
    print(f'Page #: {doc_count.value + 1}')
    for data in datas:

      print(data)

      # if new doc
      if is_new_page(data[0]):
        
        tf_idf_dict = {}
        tf_idf_dict["tf"] = calculate_tf(df_page)
        tf_idf_dict["idf"] = {}

        tf_idf_broadcast.value[doc_count.value] = tf_idf_dict   
        doc_count.add(1)

        tf_idf_broadcast.value.append(dict())

      elif is_end_of_the_book(data[0]):
        tf_idf_broadcast.value.pop()
        calculate_idf()
        
        
        dict_rdd = sc.parallelize(tf_idf_broadcast.value)
        df = dict_rdd.map(lambda d: dict(calculateTFIDFAndGetTop(d,1)))

        json = convertToJson(df.collect())

        publishToKafkaOutput(json)
        print(tf_idf_broadcast.value)
        print(json)
        
      else:
        if data[0] not in df_page:
          # if it's a new keyword for the doc set df for this keyword to 1 otherwise increase 1.
          df_page[data[0]] = data[1]
          df_broadcast.value[data[0]] = data[1]
        else:
          df_page[data[0]] += data[1] 
          df_broadcast.value[data[0]] += data[1]

# %%
kvs = KafkaUtils.createStream(ssc, kafka_bootstrap_servers, 'spark-streaming-consumer', {kafka_topic_name:1}) 
kvs = KafkaUtils.createDirectStream(ssc, [kafka_topic_name], {"metadata.broker.list": kafka_bootstrap_servers})
kvs = KafkaUtils.createDirectStream(ssc, [kafka_topic_name], {
                        'bootstrap.servers':kafka_bootstrap_servers,
                        'group.id':'test-group',
                        'auto.offset.reset':'largest'})

# %%
lines = kvs.map(lambda x: x[1])

counts1 = lines.flatMap(lambda line: line.split(' ')).map(lambda word: (word, 1))#.reduceByKey(lambda a, b: a+b)
counts1.foreachRDD(echo)
counts1.pprint()

ssc.start()

ssc.awaitTerminationOrTimeout(60)
ssc.stop()
sc.stop()
# Out:
# -------------------------------------------
# Time: 2021-09-25 03:21:17
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:18
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:19
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:21
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:22
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:23
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:24
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:25
# -------------------------------------------
#
# Page #: 1
# ('', 1)
# ('/', 1)
# ('boy', 1)
# ('lived', 1)
# ('mr', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('number', 1)
# ('four', 1)
# ('privet', 1)
# ('drive', 1)
# ('proud', 1)
# ('say', 1)
# ('perfectly', 1)
# ('normal', 1)
# ('thank', 1)
# ('much', 1)
# ('last', 1)
# ('people', 1)
# ('youd', 1)
# ('expect', 1)
# ('involved', 1)
# ('anything', 1)
# ('strange', 1)
# ('mysterious', 1)
# ('didnt', 1)
# ('hold', 1)
# ('nonsense', 1)
# ('mr', 1)
# ('dursley', 1)
# ('director', 1)
# ('firm', 1)
# ('called', 1)
# ('grunnings', 1)
# ('made', 1)
# ('drills', 1)
# ('big', 1)
# ('beefy', 1)
# ('man', 1)
# ('hardly', 1)
# ('neck', 1)
# ('although', 1)
# ('large', 1)
# ('mustache', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('thin', 1)
# ('blonde', 1)
# ('nearly', 1)
# ('twice', 1)
# ('usual', 1)
# ('amount', 1)
# ('neck', 1)
# ('came', 1)
# ('useful', 1)
# ('spent', 1)
# ('much', 1)
# ('time', 1)
# ('craning', 1)
# ('garden', 1)
# ('fences', 1)
# ('spying', 1)
# ('neighbors', 1)
# ('dursley', 1)
# ('small', 1)
# ('son', 1)
# ('called', 1)
# ('dudley', 1)
# ('opinion', 1)
# ('finer', 1)
# ('boy', 1)
# ('anywhere', 1)
# ('dursleys', 1)
# ('everything', 1)
# ('wanted', 1)
# ('also', 1)
# ('secret', 1)
# ('greatest', 1)
# ('fear', 1)
# ('somebody', 1)
# ('would', 1)
# ('discover', 1)
# ('didnt', 1)
# ('think', 1)
# ('could', 1)
# ('bear', 1)
# ('anyone', 1)
# ('found', 1)
# ('potters', 1)
# ('mrs', 1)
# ('potter', 1)
# ('mrs', 1)
# ('dursleys', 1)
# ('sister', 1)
# ('hadnt', 1)
# ('page', 1)
# ('#####', 1)
# -------------------------------------------
# Time: 2021-09-25 03:21:26
# -------------------------------------------
# ('', 1)
# ('/', 1)
# ('boy', 1)
# ('lived', 1)
# ('mr', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('number', 1)
# ('four', 1)
# ('privet', 1)
# ...
#
# Page #: 2
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('met', 1)
# ('several', 1)
# ('years', 1)
# (';', 1)
# ('fact', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('pretended', 1)
# ('didnt', 1)
# ('sister', 1)
# ('sister', 1)
# ('goodfornothing', 1)
# ('husband', 1)
# ('undursleyish', 1)
# ('possible', 1)
# ('dursleys', 1)
# ('shuddered', 1)
# ('think', 1)
# ('neighbors', 1)
# ('would', 1)
# ('say', 1)
# ('potters', 1)
# ('arrived', 1)
# ('street', 1)
# ('dursleys', 1)
# ('knew', 1)
# ('potters', 1)
# ('small', 1)
# ('son', 1)
# ('never', 1)
# ('even', 1)
# ('seen', 1)
# ('boy', 1)
# ('another', 1)
# ('good', 1)
# ('reason', 1)
# ('keeping', 1)
# ('potters', 1)
# ('away', 1)
# (';', 1)
# ('didnt', 1)
# ('want', 1)
# ('dudley', 1)
# ('mixing', 1)
# ('child', 1)
# ('like', 1)
# ('mr', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('woke', 1)
# ('dull', 1)
# ('gray', 1)
# ('tuesday', 1)
# ('story', 1)
# ('starts', 1)
# ('nothing', 1)
# ('cloudy', 1)
# ('sky', 1)
# ('outside', 1)
# ('suggest', 1)
# ('strange', 1)
# ('mysterious', 1)
# ('things', 1)
# ('would', 1)
# ('soon', 1)
# ('happening', 1)
# ('country', 1)
# ('mr', 1)
# ('dursley', 1)
# ('hummed', 1)
# ('picked', 1)
# ('boring', 1)
# ('tie', 1)
# ('work', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('gossiped', 1)
# ('away', 1)
# ('happily', 1)
# ('wrestled', 1)
# ('screaming', 1)
# ('dudley', 1)
# ('high', 1)
# ('chair', 1)
# ('none', 1)
# ('noticed', 1)
# ('large', 1)
# ('tawny', 1)
# ('owl', 1)
# ('flutter', 1)
# ('past', 1)
# ('window', 1)
# ('half', 1)
# ('past', 1)
# ('eight', 1)
# ('mr', 1)
# ('dursley', 1)
# ('picked', 1)
# ('briefcase', 1)
# ('pecked', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('cheek', 1)
# ('tried', 1)
# ('kiss', 1)
# ('dudley', 1)
# ('goodbye', 1)
# ('missed', 1)
# ('dudley', 1)
# ('tantrum', 1)
# ('throwing', 1)
# ('cereal', 1)
# ('walls', 1)
# ('little', 1)
# ('tyke', 1)
# ('chortled', 1)
# ('mr', 1)
# ('dursley', 1)
# ('left', 1)
# ('house', 1)
# ('got', 1)
# ('car', 1)
# ('backed', 1)
# ('number', 1)
# ('fours', 1)
# ('drive', 1)
# ('corner', 1)
# ('street', 1)
# ('noticed', 1)
# ('first', 1)
# ('sign', 1)
# ('something', 1)
# ('peculiar', 1)
# ('cat', 1)
# ('reading', 1)
# ('map', 1)
# ('second', 1)
# ('mr', 1)
# ('dursley', 1)
# ('didnt', 1)
# ('realize', 1)
# ('seen', 1)
# ('jerked', 1)
# ('head', 1)
# ('around', 1)
# ('look', 1)
# ('tabby', 1)
# ('cat', 1)
# ('standing', 1)
# ('corner', 1)
# ('privet', 1)
# ('drive', 1)
# ('wasnt', 1)
# ('map', 1)
# ('sight', 1)
# ('could', 1)
# ('thinking', 1)
# ('must', 1)
# ('trick', 1)
# ('light', 1)
# ('mr', 1)
# ('dursley', 1)
# ('blinked', 1)
# ('stared', 1)
# ('page', 1)
# ('#####', 1)
# -------------------------------------------
# Time: 2021-09-25 03:21:27
# -------------------------------------------
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('met', 1)
# ('several', 1)
# ('years', 1)
# ...
#
# Page #: 3
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('cat', 1)
# ('stared', 1)
# ('back', 1)
# ('mr', 1)
# ('dursley', 1)
# ('drove', 1)
# ('around', 1)
# ('corner', 1)
# ('road', 1)
# ('watched', 1)
# ('cat', 1)
# ('mirror', 1)
# ('reading', 1)
# ('sign', 1)
# ('said', 1)
# ('privet', 1)
# ('drive', 1)
# ('looking', 1)
# ('sign', 1)
# (';', 1)
# ('cats', 1)
# ('couldnt', 1)
# ('read', 1)
# ('maps', 1)
# ('signs', 1)
# ('mr', 1)
# ('dursley', 1)
# ('gave', 1)
# ('little', 1)
# ('shake', 1)
# ('put', 1)
# ('cat', 1)
# ('mind', 1)
# ('drove', 1)
# ('toward', 1)
# ('town', 1)
# ('thought', 1)
# ('nothing', 1)
# ('except', 1)
# ('large', 1)
# ('order', 1)
# ('drills', 1)
# ('hoping', 1)
# ('get', 1)
# ('day', 1)
# ('edge', 1)
# ('town', 1)
# ('drills', 1)
# ('driven', 1)
# ('mind', 1)
# ('something', 1)
# ('else', 1)
# ('sat', 1)
# ('usual', 1)
# ('morning', 1)
# ('traffic', 1)
# ('jam', 1)
# ('couldnt', 1)
# ('help', 1)
# ('noticing', 1)
# ('seemed', 1)
# ('lot', 1)
# ('strangely', 1)
# ('dressed', 1)
# ('people', 1)
# ('people', 1)
# ('cloaks', 1)
# ('mr', 1)
# ('dursley', 1)
# ('couldnt', 1)
# ('bear', 1)
# ('people', 1)
# ('dressed', 1)
# ('funny', 1)
# ('clothes', 1)
# ('getups', 1)
# ('saw', 1)
# ('young', 1)
# ('people', 1)
# ('supposed', 1)
# ('stupid', 1)
# ('new', 1)
# ('fashion', 1)
# ('drummed', 1)
# ('fingers', 1)
# ('steering', 1)
# ('wheel', 1)
# ('eyes', 1)
# ('fell', 1)
# ('huddle', 1)
# ('weirdos', 1)
# ('standing', 1)
# ('quite', 1)
# ('close', 1)
# ('whispering', 1)
# ('excitedly', 1)
# ('together', 1)
# ('mr', 1)
# ('dursley', 1)
# ('enraged', 1)
# ('see', 1)
# ('couple', 1)
# ('werent', 1)
# ('young', 1)
# (';', 1)
# ('man', 1)
# ('older', 1)
# ('wearing', 1)
# ('emeraldgreen', 1)
# ('cloak', 1)
# ('nerve', 1)
# ('struck', 1)
# ('mr', 1)
# ('dursley', 1)
# ('probably', 1)
# ('silly', 1)
# ('stunt', 1)
# ('people', 1)
# ('obviously', 1)
# ('collecting', 1)
# ('something', 1)
# ('yes', 1)
# ('would', 1)
# ('traffic', 1)
# ('moved', 1)
# ('minutes', 1)
# ('later', 1)
# ('mr', 1)
# ('dursley', 1)
# ('arrived', 1)
# ('grunnings', 1)
# ('parking', 1)
# ('lot', 1)
# ('mind', 1)
# ('back', 1)
# ('drills', 1)
# ('mr', 1)
# ('dursley', 1)
# ('always', 1)
# ('sat', 1)
# ('back', 1)
# ('window', 1)
# ('office', 1)
# ('ninth', 1)
# ('floor', 1)
# ('hadnt', 1)
# ('might', 1)
# ('found', 1)
# ('harder', 1)
# ('concentrate', 1)
# ('drills', 1)
# ('morning', 1)
# ('didnt', 1)
# ('see', 1)
# ('owls', 1)
# ('swooping', 1)
# ('past', 1)
# ('broad', 1)
# ('daylight', 1)
# ('though', 1)
# ('people', 1)
# ('street', 1)
# (';', 1)
# ('pointed', 1)
# ('gazed', 1)
# ('openmouthed', 1)
# ('owl', 1)
# ('owl', 1)
# ('sped', 1)
# ('overhead', 1)
# ('never', 1)
# ('seen', 1)
# ('owl', 1)
# ('even', 1)
# ('nighttime', 1)
# ('mr', 1)
# ('dursley', 1)
# ('however', 1)
# ('perfectly', 1)
# ('normal', 1)
# ('owlfree', 1)
# ('morning', 1)
# ('yelled', 1)
# ('five', 1)
# ('different', 1)
# ('people', 1)
# ('made', 1)
# ('several', 1)
# ('important', 1)
# ('telephone', 1)
# ('page', 1)
# ('#####', 1)
# -------------------------------------------
# Time: 2021-09-25 03:21:28
# -------------------------------------------
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('cat', 1)
# ('stared', 1)
# ('back', 1)
# ...
#
# Page #: 4
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('calls', 1)
# ('shouted', 1)
# ('bit', 1)
# ('good', 1)
# ('mood', 1)
# ('lunchtime', 1)
# ('thought', 1)
# ('hed', 1)
# ('stretch', 1)
# ('legs', 1)
# ('walk', 1)
# ('across', 1)
# ('road', 1)
# ('buy', 1)
# ('bun', 1)
# ('bakery', 1)
# ('hed', 1)
# ('forgotten', 1)
# ('people', 1)
# ('cloaks', 1)
# ('passed', 1)
# ('group', 1)
# ('next', 1)
# ('bakers', 1)
# ('eyed', 1)
# ('angrily', 1)
# ('passed', 1)
# ('didnt', 1)
# ('know', 1)
# ('made', 1)
# ('uneasy', 1)
# ('bunch', 1)
# ('whispering', 1)
# ('excitedly', 1)
# ('couldnt', 1)
# ('see', 1)
# ('single', 1)
# ('collecting', 1)
# ('tin', 1)
# ('way', 1)
# ('back', 1)
# ('past', 1)
# ('clutching', 1)
# ('large', 1)
# ('doughnut', 1)
# ('bag', 1)
# ('caught', 1)
# ('words', 1)
# ('saying', 1)
# ('potters', 1)
# ('thats', 1)
# ('right', 1)
# ('thats', 1)
# ('heard', 1)
# ('yes', 1)
# ('son', 1)
# ('harry', 1)
# ('mr', 1)
# ('dursley', 1)
# ('stopped', 1)
# ('dead', 1)
# ('fear', 1)
# ('flooded', 1)
# ('looked', 1)
# ('back', 1)
# ('whisperers', 1)
# ('wanted', 1)
# ('say', 1)
# ('something', 1)
# ('thought', 1)
# ('better', 1)
# ('dashed', 1)
# ('back', 1)
# ('across', 1)
# ('road', 1)
# ('hurried', 1)
# ('office', 1)
# ('snapped', 1)
# ('secretary', 1)
# ('disturb', 1)
# ('seized', 1)
# ('telephone', 1)
# ('almost', 1)
# ('finished', 1)
# ('dialing', 1)
# ('home', 1)
# ('number', 1)
# ('changed', 1)
# ('mind', 1)
# ('put', 1)
# ('receiver', 1)
# ('back', 1)
# ('stroked', 1)
# ('mustache', 1)
# ('thinking', 1)
# ('stupid', 1)
# ('potter', 1)
# ('wasnt', 1)
# ('unusual', 1)
# ('name', 1)
# ('sure', 1)
# ('lots', 1)
# ('people', 1)
# ('called', 1)
# ('potter', 1)
# ('son', 1)
# ('called', 1)
# ('harry', 1)
# ('come', 1)
# ('think', 1)
# ('wasnt', 1)
# ('even', 1)
# ('sure', 1)
# ('nephew', 1)
# ('called', 1)
# ('harry', 1)
# ('hed', 1)
# ('never', 1)
# ('even', 1)
# ('seen', 1)
# ('boy', 1)
# ('might', 1)
# ('harvey', 1)
# ('harold', 1)
# ('point', 1)
# ('worrying', 1)
# ('mrs', 1)
# ('dursley', 1)
# (';', 1)
# ('always', 1)
# ('got', 1)
# ('upset', 1)
# ('mention', 1)
# ('sister', 1)
# ('didnt', 1)
# ('blame', 1)
# ('hed', 1)
# ('sister', 1)
# ('like', 1)
# ('people', 1)
# ('cloaks', 1)
# ('page', 1)
# ('#####', 1)
# -------------------------------------------
# Time: 2021-09-25 03:21:29
# -------------------------------------------
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('calls', 1)
# ('shouted', 1)
# ('bit', 1)
# ...
#
# -------------------------------------------
# Time: 2021-09-25 03:21:30
# -------------------------------------------
#
# Page #: 5
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('found', 1)
# ('lot', 1)
# ('harder', 1)
# ('concentrate', 1)
# ('drills', 1)
# ('afternoon', 1)
# ('left', 1)
# ('building', 1)
# ('five', 1)
# ('oclock', 1)
# ('still', 1)
# ('worried', 1)
# ('walked', 1)
# ('straight', 1)
# ('someone', 1)
# ('outside', 1)
# ('door', 1)
# ('sorry', 1)
# ('grunted', 1)
# ('tiny', 1)
# ('old', 1)
# ('man', 1)
# ('stumbled', 1)
# ('almost', 1)
# ('fell', 1)
# ('seconds', 1)
# ('mr', 1)
# ('dursley', 1)
# ('realized', 1)
# ('man', 1)
# ('wearing', 1)
# ('violet', 1)
# ('cloak', 1)
# ('didnt', 1)
# ('seem', 1)
# ('upset', 1)
# ('almost', 1)
# ('knocked', 1)
# ('ground', 1)
# ('contrary', 1)
# ('face', 1)
# ('split', 1)
# ('wide', 1)
# ('smile', 1)
# ('said', 1)
# ('squeaky', 1)
# ('voice', 1)
# ('made', 1)
# ('passersby', 1)
# ('stare', 1)
# ('dont', 1)
# ('sorry', 1)
# ('dear', 1)
# ('sir', 1)
# ('nothing', 1)
# ('could', 1)
# ('upset', 1)
# ('today', 1)
# ('rejoice', 1)
# ('knowwho', 1)
# ('gone', 1)
# ('last', 1)
# ('even', 1)
# ('muggles', 1)
# ('like', 1)
# ('celebrating', 1)
# ('happy', 1)
# ('happy', 1)
# ('day', 1)
# ('old', 1)
# ('man', 1)
# ('hugged', 1)
# ('mr', 1)
# ('dursley', 1)
# ('around', 1)
# ('middle', 1)
# ('walked', 1)
# ('mr', 1)
# ('dursley', 1)
# ('stood', 1)
# ('rooted', 1)
# ('spot', 1)
# ('hugged', 1)
# ('complete', 1)
# ('stranger', 1)
# ('also', 1)
# ('thought', 1)
# ('called', 1)
# ('muggle', 1)
# ('whatever', 1)
# ('rattled', 1)
# ('hurried', 1)
# ('car', 1)
# ('set', 1)
# ('home', 1)
# ('hoping', 1)
# ('imagining', 1)
# ('things', 1)
# ('never', 1)
# ('hoped', 1)
# ('didnt', 1)
# ('approve', 1)
# ('imagination', 1)
# ('pulled', 1)
# ('driveway', 1)
# ('number', 1)
# ('four', 1)
# ('first', 1)
# ('thing', 1)
# ('saw', 1)
# ('didnt', 1)
# ('improve', 1)
# ('mood', 1)
# ('tabby', 1)
# ('cat', 1)
# ('hed', 1)
# ('spotted', 1)
# ('morning', 1)
# ('sitting', 1)
# ('garden', 1)
# ('wall', 1)
# ('sure', 1)
# ('one', 1)
# (';', 1)
# ('markings', 1)
# ('around', 1)
# ('eyes', 1)
# ('shoo', 1)
# ('said', 1)
# ('mr', 1)
# ('dursley', 1)
# ('loudly', 1)
# ('cat', 1)
# ('didnt', 1)
# ('move', 1)
# ('gave', 1)
# ('stern', 1)
# ('look', 1)
# ('normal', 1)
# ('cat', 1)
# ('behavior', 1)
# ('mr', 1)
# ('dursley', 1)
# ('wondered', 1)
# ('trying', 1)
# ('pull', 1)
# ('together', 1)
# ('let', 1)
# ('page', 1)
# ('#####', 1)
# -------------------------------------------
# Time: 2021-09-25 03:21:31
# -------------------------------------------
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('found', 1)
# ('lot', 1)
# ('harder', 1)
# ...
#
# Page #: 6
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('house', 1)
# ('still', 1)
# ('determined', 1)
# ('mention', 1)
# ('anything', 1)
# ('wife', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('nice', 1)
# ('normal', 1)
# ('day', 1)
# ('told', 1)
# ('dinner', 1)
# ('mrs', 1)
# ('next', 1)
# ('doors', 1)
# ('problems', 1)
# ('daughter', 1)
# ('dudley', 1)
# ('learned', 1)
# ('new', 1)
# ('word', 1)
# ('(', 1)
# ('wont', 1)
# (')', 1)
# ('mr', 1)
# ('dursley', 1)
# ('tried', 1)
# ('act', 1)
# ('normally', 1)
# ('dudley', 1)
# ('put', 1)
# ('bed', 1)
# ('went', 1)
# ('living', 1)
# ('room', 1)
# ('time', 1)
# ('catch', 1)
# ('last', 1)
# ('report', 1)
# ('evening', 1)
# ('news', 1)
# (':', 1)
# ('finally', 1)
# ('birdwatchers', 1)
# ('everywhere', 1)
# ('reported', 1)
# ('nations', 1)
# ('owls', 1)
# ('behaving', 1)
# ('unusually', 1)
# ('today', 1)
# ('although', 1)
# ('owls', 1)
# ('normally', 1)
# ('hunt', 1)
# ('night', 1)
# ('hardly', 1)
# ('ever', 1)
# ('seen', 1)
# ('daylight', 1)
# ('hundreds', 1)
# ('sightings', 1)
# ('birds', 1)
# ('flying', 1)
# ('every', 1)
# ('direction', 1)
# ('since', 1)
# ('sunrise', 1)
# ('experts', 1)
# ('unable', 1)
# ('explain', 1)
# ('owls', 1)
# ('suddenly', 1)
# ('changed', 1)
# ('sleeping', 1)
# ('pattern', 1)
# ('newscaster', 1)
# ('allowed', 1)
# ('grin', 1)
# ('mysterious', 1)
# ('jim', 1)
# ('mcguffin', 1)
# ('weather', 1)
# ('going', 1)
# ('showers', 1)
# ('owls', 1)
# ('tonight', 1)
# ('jim', 1)
# ('well', 1)
# ('ted', 1)
# ('said', 1)
# ('weatherman', 1)
# ('dont', 1)
# ('know', 1)
# ('owls', 1)
# ('acting', 1)
# ('oddly', 1)
# ('today', 1)
# ('viewers', 1)
# ('far', 1)
# ('apart', 1)
# ('kent', 1)
# ('yorkshire', 1)
# ('dundee', 1)
# ('phoning', 1)
# ('tell', 1)
# ('instead', 1)
# ('rain', 1)
# ('promised', 1)
# ('yesterday', 1)
# ('theyve', 1)
# ('downpour', 1)
# ('shooting', 1)
# ('stars', 1)
# ('perhaps', 1)
# ('people', 1)
# ('celebrating', 1)
# ('bonfire', 1)
# ('night', 1)
# ('early', 1)
# ('next', 1)
# ('week', 1)
# ('folks', 1)
# ('promise', 1)
# ('wet', 1)
# ('night', 1)
# ('tonight', 1)
# ('mr', 1)
# ('dursley', 1)
# ('sat', 1)
# ('frozen', 1)
# ('armchair', 1)
# ('shooting', 1)
# ('stars', 1)
# ('britain', 1)
# ('owls', 1)
# ('flying', 1)
# ('daylight', 1)
# ('mysterious', 1)
# ('people', 1)
# ('cloaks', 1)
# ('place', 1)
# ('whisper', 1)
# ('whisper', 1)
# ('potters', 1)
# ('page', 1)
# ('#####', 1)
# -------------------------------------------
# Time: 2021-09-25 03:21:32
# -------------------------------------------
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('house', 1)
# ('still', 1)
# ('determined', 1)
# ...
#
# Page #: 7
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('came', 1)
# ('living', 1)
# ('room', 1)
# ('carrying', 1)
# ('two', 1)
# ('cups', 1)
# ('tea', 1)
# ('good', 1)
# ('hed', 1)
# ('say', 1)
# ('something', 1)
# ('cleared', 1)
# ('throat', 1)
# ('nervously', 1)
# ('er', 1)
# ('petunia', 1)
# ('dear', 1)
# ('havent', 1)
# ('heard', 1)
# ('sister', 1)
# ('lately', 1)
# ('expected', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('looked', 1)
# ('shocked', 1)
# ('angry', 1)
# ('normally', 1)
# ('pretended', 1)
# ('didnt', 1)
# ('sister', 1)
# ('said', 1)
# ('sharply', 1)
# ('funny', 1)
# ('stuff', 1)
# ('news', 1)
# ('mr', 1)
# ('dursley', 1)
# ('mumbled', 1)
# ('owls', 1)
# ('shooting', 1)
# ('stars', 1)
# ('lot', 1)
# ('funnylooking', 1)
# ('people', 1)
# ('town', 1)
# ('today', 1)
# ('snapped', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('well', 1)
# ('thought', 1)
# ('maybe', 1)
# ('something', 1)
# ('know', 1)
# ('crowd', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('sipped', 1)
# ('tea', 1)
# ('pursed', 1)
# ('lips', 1)
# ('mr', 1)
# ('dursley', 1)
# ('wondered', 1)
# ('whether', 1)
# ('dared', 1)
# ('tell', 1)
# ('hed', 1)
# ('heard', 1)
# ('name', 1)
# ('potter', 1)
# ('decided', 1)
# ('didnt', 1)
# ('dare', 1)
# ('instead', 1)
# ('said', 1)
# ('casually', 1)
# ('could', 1)
# ('son', 1)
# ('hed', 1)
# ('dudleys', 1)
# ('age', 1)
# ('wouldnt', 1)
# ('suppose', 1)
# ('said', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('stiffly', 1)
# ('whats', 1)
# ('name', 1)
# ('howard', 1)
# ('isnt', 1)
# ('harry', 1)
# ('nasty', 1)
# ('common', 1)
# ('name', 1)
# ('ask', 1)
# ('oh', 1)
# ('yes', 1)
# ('said', 1)
# ('mr', 1)
# ('dursley', 1)
# ('heart', 1)
# ('sinking', 1)
# ('horribly', 1)
# ('yes', 1)
# ('quite', 1)
# ('agree', 1)
# ('didnt', 1)
# ('say', 1)
# ('another', 1)
# ('word', 1)
# ('subject', 1)
# ('went', 1)
# ('upstairs', 1)
# ('bed', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('bathroom', 1)
# ('mr', 1)
# ('dursley', 1)
# ('crept', 1)
# ('bedroom', 1)
# ('window', 1)
# ('page', 1)
# ('#####', 1)
# -------------------------------------------
# Time: 2021-09-25 03:21:33
# -------------------------------------------
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('came', 1)
# ...
#
# Page #: 8
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('peered', 1)
# ('front', 1)
# ('garden', 1)
# ('cat', 1)
# ('still', 1)
# ('staring', 1)
# ('privet', 1)
# ('drive', 1)
# ('though', 1)
# ('waiting', 1)
# ('something', 1)
# ('imagining', 1)
# ('things', 1)
# ('could', 1)
# ('anything', 1)
# ('potters', 1)
# ('got', 1)
# ('related', 1)
# ('pair', 1)
# ('well', 1)
# ('didnt', 1)
# ('think', 1)
# ('could', 1)
# ('bear', 1)
# ('dursleys', 1)
# ('got', 1)
# ('bed', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('fell', 1)
# ('asleep', 1)
# ('quickly', 1)
# ('mr', 1)
# ('dursley', 1)
# ('lay', 1)
# ('awake', 1)
# ('turning', 1)
# ('mind', 1)
# ('last', 1)
# ('comforting', 1)
# ('thought', 1)
# ('fell', 1)
# ('asleep', 1)
# ('even', 1)
# ('potters', 1)
# ('involved', 1)
# ('reason', 1)
# ('come', 1)
# ('near', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('potters', 1)
# ('knew', 1)
# ('well', 1)
# ('petunia', 1)
# ('thought', 1)
# ('kind', 1)
# ('couldnt', 1)
# ('see', 1)
# ('petunia', 1)
# ('could', 1)
# ('get', 1)
# ('mixed', 1)
# ('anything', 1)
# ('might', 1)
# ('going', 1)
# ('yawned', 1)
# ('turned', 1)
# ('couldnt', 1)
# ('affect', 1)
# ('wrong', 1)
# ('mr', 1)
# ('dursley', 1)
# ('might', 1)
# ('drifting', 1)
# ('uneasy', 1)
# ('sleep', 1)
# ('cat', 1)
# ('wall', 1)
# ('outside', 1)
# ('showing', 1)
# ('sign', 1)
# ('sleepiness', 1)
# ('sitting', 1)
# ('still', 1)
# ('statue', 1)
# ('eyes', 1)
# ('fixed', 1)
# ('unblinkingly', 1)
# ('far', 1)
# ('corner', 1)
# ('privet', 1)
# ('drive', 1)
# ('didnt', 1)
# ('much', 1)
# ('quiver', 1)
# ('car', 1)
# ('door', 1)
# ('slammed', 1)
# ('next', 1)
# ('street', 1)
# ('two', 1)
# ('owls', 1)
# ('swooped', 1)
# ('overhead', 1)
# ('fact', 1)
# ('nearly', 1)
# ('midnight', 1)
# ('cat', 1)
# ('moved', 1)
# ('man', 1)
# ('appeared', 1)
# ('corner', 1)
# ('cat', 1)
# ('watching', 1)
# ('appeared', 1)
# ('suddenly', 1)
# ('silently', 1)
# ('youd', 1)
# ('thought', 1)
# ('hed', 1)
# ('popped', 1)
# ('ground', 1)
# ('cats', 1)
# ('tail', 1)
# ('twitched', 1)
# ('eyes', 1)
# ('narrowed', 1)
# ('nothing', 1)
# ('like', 1)
# ('man', 1)
# ('ever', 1)
# ('seen', 1)
# ('privet', 1)
# ('drive', 1)
# ('tall', 1)
# ('thin', 1)
# ('old', 1)
# ('judging', 1)
# ('silver', 1)
# ('hair', 1)
# ('beard', 1)
# ('long', 1)
# ('page', 1)
# ('#####', 1)
# -------------------------------------------
# Time: 2021-09-25 03:21:34
# -------------------------------------------
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('peered', 1)
# ('front', 1)
# ('garden', 1)
# ...
#
# Page #: 9
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('enough', 1)
# ('tuck', 1)
# ('belt', 1)
# ('wearing', 1)
# ('long', 1)
# ('robes', 1)
# ('purple', 1)
# ('cloak', 1)
# ('swept', 1)
# ('ground', 1)
# ('highheeled', 1)
# ('buckled', 1)
# ('boots', 1)
# ('blue', 1)
# ('eyes', 1)
# ('light', 1)
# ('bright', 1)
# ('sparkling', 1)
# ('behind', 1)
# ('halfmoon', 1)
# ('spectacles', 1)
# ('nose', 1)
# ('long', 1)
# ('crooked', 1)
# ('though', 1)
# ('broken', 1)
# ('least', 1)
# ('twice', 1)
# ('mans', 1)
# ('name', 1)
# ('albus', 1)
# ('dumbledore', 1)
# ('albus', 1)
# ('dumbledore', 1)
# ('didnt', 1)
# ('seem', 1)
# ('realize', 1)
# ('arrived', 1)
# ('street', 1)
# ('everything', 1)
# ('name', 1)
# ('boots', 1)
# ('unwelcome', 1)
# ('busy', 1)
# ('rummaging', 1)
# ('cloak', 1)
# ('looking', 1)
# ('something', 1)
# ('seem', 1)
# ('realize', 1)
# ('watched', 1)
# ('looked', 1)
# ('suddenly', 1)
# ('cat', 1)
# ('still', 1)
# ('staring', 1)
# ('end', 1)
# ('street', 1)
# ('reason', 1)
# ('sight', 1)
# ('cat', 1)
# ('seemed', 1)
# ('amuse', 1)
# ('chuckled', 1)
# ('muttered', 1)
# ('known', 1)
# ('found', 1)
# ('looking', 1)
# ('inside', 1)
# ('pocket', 1)
# ('seemed', 1)
# ('silver', 1)
# ('cigarette', 1)
# ('lighter', 1)
# ('flicked', 1)
# ('open', 1)
# ('held', 1)
# ('air', 1)
# ('clicked', 1)
# ('nearest', 1)
# ('street', 1)
# ('lamp', 1)
# ('went', 1)
# ('little', 1)
# ('pop', 1)
# ('clicked', 1)
# ('next', 1)
# ('lamp', 1)
# ('flickered', 1)
# ('darkness', 1)
# ('twelve', 1)
# ('times', 1)
# ('clicked', 1)
# ('putouter', 1)
# ('lights', 1)
# ('left', 1)
# ('whole', 1)
# ('street', 1)
# ('two', 1)
# ('tiny', 1)
# ('pinpricks', 1)
# ('distance', 1)
# ('eyes', 1)
# ('cat', 1)
# ('watching', 1)
# ('anyone', 1)
# ('looked', 1)
# ('window', 1)
# ('even', 1)
# ('beadyeyed', 1)
# ('mrs', 1)
# ('dursley', 1)
# ('wouldnt', 1)
# ('able', 1)
# ('see', 1)
# ('anything', 1)
# ('happening', 1)
# ('pavement', 1)
# ('dumbledore', 1)
# ('slipped', 1)
# ('put', 1)
# ('outer', 1)
# ('back', 1)
# ('inside', 1)
# ('cloak', 1)
# ('set', 1)
# ('street', 1)
# ('toward', 1)
# ('number', 1)
# ('four', 1)
# ('sat', 1)
# ('wall', 1)
# ('next', 1)
# ('cat', 1)
# ('didnt', 1)
# ('look', 1)
# ('moment', 1)
# ('spoke', 1)
# ('fancy', 1)
# ('seeing', 1)
# ('professor', 1)
# ('mcgonagall', 1)
# ('page', 1)
# ('#####', 1)
# -------------------------------------------
# Time: 2021-09-25 03:21:35
# -------------------------------------------
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('enough', 1)
# ('tuck', 1)
# ('belt', 1)
# ...
#
# Page #: 10
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('turned', 1)
# ('smile', 1)
# ('tabby', 1)
# ('gone', 1)
# ('instead', 1)
# ('smiling', 1)
# ('rather', 1)
# ('severelooking', 1)
# ('woman', 1)
# ('wearing', 1)
# ('square', 1)
# ('glasses', 1)
# ('exactly', 1)
# ('shape', 1)
# ('markings', 1)
# ('cat', 1)
# ('around', 1)
# ('eyes', 1)
# ('wearing', 1)
# ('cloak', 1)
# ('emerald', 1)
# ('one', 1)
# ('black', 1)
# ('hair', 1)
# ('drawn', 1)
# ('tight', 1)
# ('bun', 1)
# ('looked', 1)
# ('distinctly', 1)
# ('ruffled', 1)
# ('know', 1)
# ('asked', 1)
# ('dear', 1)
# ('professor', 1)
# ('ive', 1)
# ('never', 1)
# ('seen', 1)
# ('cat', 1)
# ('sit', 1)
# ('stiffly', 1)
# ('youd', 1)
# ('stiff', 1)
# ('youd', 1)
# ('sitting', 1)
# ('brick', 1)
# ('wall', 1)
# ('day', 1)
# ('said', 1)
# ('professor', 1)
# ('mcgonagall', 1)
# ('day', 1)
# ('could', 1)
# ('celebrating', 1)
# ('must', 1)
# ('passed', 1)
# ('dozen', 1)
# ('feasts', 1)
# ('parties', 1)
# ('way', 1)
# ('professor', 1)
# ('mcgonagall', 1)
# ('sniffed', 1)
# ('angrily', 1)
# ('oh', 1)
# ('yes', 1)
# ('everyones', 1)
# ('celebrating', 1)
# ('right', 1)
# ('said', 1)
# ('impatiently', 1)
# ('youd', 1)
# ('think', 1)
# ('theyd', 1)
# ('bit', 1)
# ('careful', 1)
# ('even', 1)
# ('muggles', 1)
# ('noticed', 1)
# ('somethings', 1)
# ('going', 1)
# ('news', 1)
# ('jerked', 1)
# ('head', 1)
# ('back', 1)
# ('dursleys', 1)
# ('dark', 1)
# ('livingroom', 1)
# ('window', 1)
# ('heard', 1)
# ('flocks', 1)
# ('owls', 1)
# ('shooting', 1)
# ('stars', 1)
# ('well', 1)
# ('theyre', 1)
# ('completely', 1)
# ('stupid', 1)
# ('bound', 1)
# ('notice', 1)
# ('something', 1)
# ('shooting', 1)
# ('stars', 1)
# ('kent', 1)
# ('ill', 1)
# ('bet', 1)
# ('dedalus', 1)
# ('diggle', 1)
# ('never', 1)
# ('much', 1)
# ('sense', 1)
# ('cant', 1)
# ('blame', 1)
# ('said', 1)
# ('dumbledore', 1)
# ('gently', 1)
# ('weve', 1)
# ('precious', 1)
# ('little', 1)
# ('celebrate', 1)
# ('eleven', 1)
# ('years', 1)
# ('know', 1)
# ('said', 1)
# ('professor', 1)
# ('mcgonagall', 1)
# ('irritably', 1)
# ('thats', 1)
# ('reason', 1)
# ('lose', 1)
# ('heads', 1)
# ('people', 1)
# ('downright', 1)
# ('careless', 1)
# ('streets', 1)
# ('broad', 1)
# ('page', 1)
# ('#####', 1)
# -------------------------------------------
# Time: 2021-09-25 03:21:36
# -------------------------------------------
# ('', 1)
# ('harry', 1)
# ('potter', 1)
# ('philosophers', 1)
# ('stone', 1)
# ('jk', 1)
# ('rowling', 1)
# ('turned', 1)
# ('smile', 1)
# ('tabby', 1)
# ...
#
# Page #: 11
# ('@@@@@@@', 1)
# Message delivered to stream-expresso-output [0]
# [{'tf': {'': 0.010416666666666666, '/': 0.010416666666666666, 'boy': 0.020833333333333332, 'lived': 0.010416666666666666, 'mr': 0.020833333333333332, 'mrs': 0.041666666666666664, 'dursley': 0.041666666666666664, 'number': 0.010416666666666666, 'four': 0.010416666666666666, 'privet': 0.010416666666666666, 'drive': 0.010416666666666666, 'proud': 0.010416666666666666, 'say': 0.010416666666666666, 'perfectly': 0.010416666666666666, 'normal': 0.010416666666666666, 'thank': 0.010416666666666666, 'much': 0.020833333333333332, 'last': 0.010416666666666666, 'people': 0.010416666666666666, 'youd': 0.010416666666666666, 'expect': 0.010416666666666666, 'involved': 0.010416666666666666, 'anything': 0.010416666666666666, 'strange': 0.010416666666666666, 'mysterious': 0.010416666666666666, 'didnt': 0.020833333333333332, 'hold': 0.010416666666666666, 'nonsense': 0.010416666666666666, 'director': 0.010416666666666666, 'firm': 0.010416666666666666, 'called': 0.020833333333333332, 'grunnings': 0.010416666666666666, 'made': 0.010416666666666666, 'drills': 0.010416666666666666, 'big': 0.010416666666666666, 'beefy': 0.010416666666666666, 'man': 0.010416666666666666, 'hardly': 0.010416666666666666, 'neck': 0.020833333333333332, 'although': 0.010416666666666666, 'large': 0.010416666666666666, 'mustache': 0.010416666666666666, 'thin': 0.010416666666666666, 'blonde': 0.010416666666666666, 'nearly': 0.010416666666666666, 'twice': 0.010416666666666666, 'usual': 0.010416666666666666, 'amount': 0.010416666666666666, 'came': 0.010416666666666666, 'useful': 0.010416666666666666, 'spent': 0.010416666666666666, 'time': 0.010416666666666666, 'craning': 0.010416666666666666, 'garden': 0.010416666666666666, 'fences': 0.010416666666666666, 'spying': 0.010416666666666666, 'neighbors': 0.010416666666666666, 'small': 0.010416666666666666, 'son': 0.010416666666666666, 'dudley': 0.010416666666666666, 'opinion': 0.010416666666666666, 'finer': 0.010416666666666666, 'anywhere': 0.010416666666666666, 'dursleys': 0.020833333333333332, 'everything': 0.010416666666666666, 'wanted': 0.010416666666666666, 'also': 0.010416666666666666, 'secret': 0.010416666666666666, 'greatest': 0.010416666666666666, 'fear': 0.010416666666666666, 'somebody': 0.010416666666666666, 'would': 0.010416666666666666, 'discover': 0.010416666666666666, 'think': 0.010416666666666666, 'could': 0.010416666666666666, 'bear': 0.010416666666666666, 'anyone': 0.010416666666666666, 'found': 0.010416666666666666, 'potters': 0.010416666666666666, 'potter': 0.010416666666666666, 'sister': 0.010416666666666666, 'hadnt': 0.010416666666666666, 'page': 0.010416666666666666}, 'idf': {'': 1.0, '/': 1.7403626894942439, 'boy': 1.4393326938302626, 'lived': 1.7403626894942439, 'mr': 1.0871501757189002, 'mrs': 1.1383026981662814, 'dursley': 1.0413926851582251, 'number': 1.2632414347745815, 'four': 1.4393326938302626, 'privet': 1.3424226808222062, 'drive': 1.3424226808222062, 'proud': 1.7403626894942439, 'say': 1.3424226808222062, 'perfectly': 1.5642714304385625, 'normal': 1.3424226808222062, 'thank': 1.7403626894942439, 'much': 1.4393326938302626, 'last': 1.3424226808222062, 'people': 1.1962946451439682, 'youd': 1.4393326938302626, 'expect': 1.7403626894942439, 'involved': 1.5642714304385625, 'anything': 1.3424226808222062, 'strange': 1.5642714304385625, 'mysterious': 1.4393326938302626, 'didnt': 1.0871501757189002, 'hold': 1.7403626894942439, 'nonsense': 1.7403626894942439, 'director': 1.7403626894942439, 'firm': 1.7403626894942439, 'called': 1.4393326938302626, 'grunnings': 1.5642714304385625, 'made': 1.3424226808222062, 'drills': 1.4393326938302626, 'big': 1.7403626894942439, 'beefy': 1.7403626894942439, 'man': 1.3424226808222062, 'hardly': 1.5642714304385625, 'neck': 1.7403626894942439, 'although': 1.5642714304385625, 'large': 1.3424226808222062, 'mustache': 1.5642714304385625, 'thin': 1.5642714304385625, 'blonde': 1.7403626894942439, 'nearly': 1.5642714304385625, 'twice': 1.5642714304385625, 'usual': 1.5642714304385625,  ...
# {
#     "page1": {
#         "mrs": 0.04742927909026172
#     },
#     "page2": {
#         "dursley": 0.0544914777117676
#     },
#     "page3": {
#         "mr": 0.04392525962500607
#     },
#     "page4": {
#         "hed": 0.0360381927737505
#     },
#     "page5": {
#         "mr": 0.03484455691406731
#     },
#     "page6": {
#         "owls": 0.04921719875745122
#     },
#     "page7": {
#         "dursley": 0.07714019890060926
#     },
#     "page8": {
#         "cat": 0.031689924374674654
#     },
#     "page9": {
#         "street": 0.04474742269407354
#     },
#     "page10": {
#         "professor": 0.04375584420807168
#     }
# }
# -------------------------------------------
# Time: 2021-09-25 03:21:37
# -------------------------------------------
# ('@@@@@@@', 1)
#
# -------------------------------------------
# Time: 2021-09-25 03:21:38
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:39
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:41
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:42
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:43
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:44
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:46
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:47
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:48
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:49
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:51
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:52
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:53
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:54
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:56
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:57
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:58
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:21:59
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:01
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:02
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:03
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:04
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:06
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:07
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:08
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:09
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:11
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:12
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:13
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:14
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:16
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:17
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:18
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:19
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:21
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:22
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:23
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:24
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-09-25 03:22:26
# -------------------------------------------

# %%
ssc.stop()
sc.stop()
